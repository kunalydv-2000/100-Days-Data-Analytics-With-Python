# %% [markdown]
# # Mini Project (Day-1)
# - ## student profile

# %%
name = "Rahul"
age = 22
course = "Data Analytics"
city = "Delhi"

print("----- Student Profile -----")
print(f"Name : {name}")
print(f"Age : {age}")
print(f"Course : {course}")
print(f"City : {city}")
# Out:
# ----- Student Profile -----
# Name : Rahul
# Age : 22
# Course : Data Analytics
# City : Delhi
