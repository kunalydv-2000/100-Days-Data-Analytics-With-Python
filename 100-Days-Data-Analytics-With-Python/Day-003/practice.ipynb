# %% [markdown]
# # exercise 1

# %%
language = "Python"

print(language[0])
print(language[-1])
# Out:
# P
# n

# %% [markdown]
# # exercise 2

# %%
course = "Data Analytics"
print(len(course))
print(course.upper())
print(course.lower())
# Out:
# 14
# DATA ANALYTICS
# data analytics

# %% [markdown]
# # exercise 3

# %%
sent1 = "I love Java"
print(sent1.replace('Java','Python'))
# Out:
# I love Python

# %% [markdown]
# # exercise 4

# %%
course = "Data Analytics"
'Analytics' in course
# Out:
# True
