# %% [markdown]
# # exercise 1
# ---

# %%
name = "Rahul"
print(name)
print(type(name))
# Out:
# Rahul
# <class 'str'>

# %% [markdown]
# # exercise 2
# ---

# %%
age = 25 
print(age)
print(type(age))
# Out:
# 25
# <class 'int'>

# %% [markdown]
# # exercise 3
# ---

# %%
salary = 50000.50
print(salary)
print(type(salary))
# Out:
# 50000.5
# <class 'float'>

# %% [markdown]
# # exercise 4
# ---

# %%
is_student = True 
print(is_student) 
print(type(is_student))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# # exercise 5
# ---

# %%
print(type("Python"))
print(type(100))
print(type(99.99)) 
print(type(False))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# # exercise 6
# ---

# %%
age = "25" 
new_age = int(age) 
print(new_age) 
print(type(new_age))
# Out:
# 25
# <class 'int'>

# %% [markdown]
# # exercise 7
# ---

# %%
score = 100
new_score = str(score)
print(new_score)
print(type(new_score))
# Out:
# 100
# <class 'str'>

# %% [markdown]
# # exercise 8
# ---

# %%
number = 50
number_float = float(number)
print(number_float) 
print(type(number_float))
# Out:
# 50.0
# <class 'float'>

# %% [markdown]
# # exercise 9
# ---

# %%
price = 99.99
price_int = int(price) 
print(price_int)
print(type(price_int))
# Out:
# 99
# <class 'int'>

# %% [markdown]
# # exercise 10
# ---

# %%
print(bool(1))
print(bool(0))
print(bool("Python"))
print(bool(""))
# Out:
# True
# False
# True
# False

# %% [markdown]
# # exercise 11
# ---

# %%
name = input("Enter your name: ")
print(f"Welcome {name}")
# Out:
# Welcome kunal

# %% [markdown]
# # exercise 12
# ---

# %%
age = int(input("Enter your age: "))
future_age = age + 5 
print(f"Your age after 5 years will be {future_age}")
# Out:
# Your age after 5 years will be 31

# %% [markdown]
# # exercise 13
# ---

# %%
num1 = int(input("Enter first number: ")) 
num2 = int(input("Enter second number: ")) 
print("Sum =", num1 + num2)
# Out:
# Sum = 82

# %%
name = input("Enter name: ")
age = int(input("Enter age: "))
marks = float(input("Enter marks: ")) 
print("\nStudent Information")
print("-------------------")
print(f"Name : {name}")
print(f"Age : {age}") 
print(f"Marks : {marks}")
# Out:
# Student Information
# -------------------
# Name : kunal
# Age : 26
# Marks : 70.0
