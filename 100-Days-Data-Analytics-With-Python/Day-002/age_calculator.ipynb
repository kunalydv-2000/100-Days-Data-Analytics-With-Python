# %% [markdown]
# # Age Calculator

# %%
print("===== AGE CALCULATOR =====")
name = input("Enter your name: ")
birth_year = int(input("Enter your birth year: "))
current_year = 2026
age = current_year - birth_year
print("\n----- RESULT -----")
print(f"Hello {name}!")
print(f"You are approximately {age} years old.")
# Out:
# ===== AGE CALCULATOR =====
#
# ----- RESULT -----
# Hello kunal!
# You are approximately 26 years old.

# %%
future_age = age + 5

print(f"In 5 years, you will be {future_age} years old.")

print("\nThank you for using the Age Calculator!")
# Out:
# In 5 years, you will be 31 years old.
#
# Thank you for using the Age Calculator!
